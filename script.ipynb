# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/lsvieira2/Documents/script-py/Laptop_pre.csv')

# %%
df.head(10)
# Out:
#     Brand     Model  Series Processor Processor_Gen   RAM Hard_Disk_Capacity  \
# 0    DELL  Inspiron     NaN        i3          11th   8.0           1 TB HDD
# 1    DELL    Vostro     NaN        i5          11th   8.0           1 TB HDD
# 2    ASUS  VivoBook      15        i3          10th   8.0         512 GB SSD
# 3    DELL  Inspiron     NaN        i3          11th   8.0           1 TB HDD
# 4    ASUS       TUF  Gaming        i5          10th   8.0         512 GB SSD
# 5    ASUS     Ryzen       3     3250U           3rd   8.0         256 GB SSD
# 6    DELL  Inspiron  Athlon     3050U             -   4.0         256 GB SSD
# 7    DELL  Inspiron     NaN        i5          11th  16.0         512 GB SSD
# 8  Lenovo   IdeaPad       3        i3          10th   8.0           1 TB HDD
# 9      HP       NaN     NaN        i5          11th   8.0         512 GB SSD
#
#   Operacional System  Rating  Price
# 0    Windows 11 Home     3.7  39040
# 1    Windows 10 Home     3.6  50840
# 2    Windows 11 Home     4.3  37940
# 3         256 GB SSD     4.4  44440
# 4    Windows 10 Home     4.5  57940
# 5    Windows 10 Home     4.3  35940
# 6    Windows 11 Home     4.2  33940
# 7         Windows 10     4.2  69040
# 8    Windows 10 Home     4.1  37440
# 9    Windows 11 Home     4.4  56449

# %%
selecao = (df['Hard_Disk_Capacity'] == '256 GB SSD') & (df['Rating'] > 4.0)
df[selecao].reset_index(drop=True)
# Out:
#      Brand     Model  Series Processor Processor_Gen  RAM Hard_Disk_Capacity  \
# 0     ASUS     Ryzen       3     3250U           3rd  8.0         256 GB SSD
# 1     DELL  Inspiron  Athlon     3050U             -  4.0         256 GB SSD
# 2   Lenovo   IdeaPad       3        i3          11th  8.0         256 GB SSD
# 3   Lenovo   IdeaPad       3        i3          10th  8.0         256 GB SSD
# 4     DELL  Inspiron   Ryzen     3250U             -  8.0         256 GB SSD
# 5       HP     Ryzen       3     3250U             -  8.0         256 GB SSD
# 6   Lenovo   IdeaPad       3        i3          11th  8.0         256 GB SSD
# 7     ASUS       NaN     NaN        i3          11th  8.0         256 GB SSD
# 8     ASUS  Vivobook      14        i3          11th  8.0         256 GB SSD
# 9     ASUS  VivoBook      15         -            (4  4.0         256 GB SSD
# 10    ASUS  VivoBook      15        i3          11th  4.0         256 GB SSD
# 11  Lenovo   IdeaPad       3        i3          11th  8.0         256 GB SSD
# 12    DELL    Vostro     NaN        i3          11th  8.0         256 GB SSD
# 13    DELL  Inspiron     NaN        i3          11th  8.0         256 GB SSD
# 14  Lenovo       NaN     NaN        i3          11th  4.0         256 GB SSD
# 15    DELL    Vostro    3405     3450U             -  8.0         256 GB SSD
# 16    DELL    Vostro     NaN        i3          10th  8.0         256 GB SSD
# 17    ASUS  VivoBook     K15        i3          11th  8.0         256 GB SSD
# 18  Lenovo   IdeaPad       3        i3          11th  8.0         256 GB SSD
# 19  realme      Book  (Slim)        i3          11th  8.0         256 GB SSD
# 20  Lenovo   IdeaPad       3        i3          11th  8.0         256 GB SSD
# 21    ASUS  Vivobook      14         -            (8  8.0         256 GB SSD
# 22    ASUS  Vivobook      14        i3          11th  4.0         256 GB SSD
# 23  Lenovo   IdeaPad       3        i3          11th  8.0         256 GB SSD
# 24  Lenovo   IdeaPad       3        i3          11th  8.0         256 GB SSD
#
#    Operacional System  Rating  Price
# 0     Windows 10 Home     4.3  35940
# 1     Windows 11 Home     4.2  33940
# 2     Windows 11 Home     4.2  40940
# 3     Windows 11 Home     4.3  37940
# 4     Windows 11 Home     4.3  37340
# 5     Windows 10 Home     4.3  38940
# 6     Windows 11 Home     4.3  40940
# 7     Windows 11 Home     4.4  38940
# 8     Windows 10 Home     4.3  37840
# 9     Windows 10 Home     4.3  34940
# 10    Windows 10 Home     4.2  36940
# 11    Windows 11 Home     4.3  39940
# 12         Windows 10     4.3  41740
# 13    Windows 11 Home     4.3  41540
# 14    Windows 10 Home     4.3  36940
# 15    Windows 10 Home     4.2  44440
# 16    Windows 10 Home     4.3  41440
# 17    Windows 11 Home     4.5  46940
# 18    Windows 11 Home     4.2  40940
# 19    Windows 10 Home     4.4  46940
# 20    Windows 11 Home     4.3  39940
# 21    Windows 11 Home     4.3  32940
# 22    Windows 10 Home     4.2  36940
# 23    Windows 11 Home     4.3  39940
# 24    Windows 11 Home     4.3  39940

# %%
os = df.query('Hard_Disk_Capacity == "256 GB SSD" and Rating >= 4.3')
os.head()
# Out:
#      Brand     Model Series Processor Processor_Gen  RAM Hard_Disk_Capacity  \
# 5     ASUS     Ryzen      3     3250U           3rd  8.0         256 GB SSD
# 12  Lenovo   IdeaPad      3        i3          10th  8.0         256 GB SSD
# 13    DELL  Inspiron  Ryzen     3250U             -  8.0         256 GB SSD
# 14      HP     Ryzen      3     3250U             -  8.0         256 GB SSD
# 15  Lenovo   IdeaPad      3        i3          11th  8.0         256 GB SSD
#
#    Operacional System  Rating  Price
# 5     Windows 10 Home     4.3  35940
# 12    Windows 11 Home     4.3  37940
# 13    Windows 11 Home     4.3  37340
# 14    Windows 10 Home     4.3  38940
# 15    Windows 11 Home     4.3  40940

# %%
od = df.query('(Hard_Disk_Capacity == "256 GB SSD" or Hard_Disk_Capacity == "512 GB SSD") and Rating > 4.7')
od.head().reset_index(drop=True)
# Out:
#   Brand     Model Series Processor Processor_Gen  RAM Hard_Disk_Capacity  \
# 0  ASUS  VivoBook  Ultra        i3          11th  8.0         512 GB SSD
#
#   Operacional System  Rating  Price
# 0    Windows 11 Home     4.8  42940
